# %%
import pandas as pd

# %% [markdown]
# ### Load the Excel files

# %%
buyer_order_df = pd.read_excel("../Dataset/BuyerOrder.xlsx")
current_stock_df = pd.read_excel("../Dataset/CurrentStock.xlsx")
metadata_buyer_order_df = pd.read_excel("../Dataset/metadata-BuyerOrder.xlsx")
metadata_current_stock_df = pd.read_excel("../Dataset/metadata-CurrentStock.xlsx")

# %%
# Display first few rows of each to inspect structure
buyer_order_head = buyer_order_df.head()
buyer_order_head
# Out:
#       BuyerName        BuyerOrderNo BuyerOrderStatus  \
# 0  shikha buyer  WFXCompany/OC217.1        Cancelled
# 1  Ashhar Buyer            116180.1        Confirmed
# 2  Ashhar Buyer            116181.1        Confirmed
# 3  Ashhar Buyer            116184.1        Cancelled
# 4  Ashhar Buyer            116186.1        Confirmed
#
#                            StyleName                   StyleCode  \
# 0  WFX SAMPLE THREAD_2200005_2200005  SEW-THREAD-WFXSAMPLETHREAD
# 1           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 2           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 3           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 4           WFX SAMPLE STYLE_2200006                 JAYDEE10001
#
#    ProductGroup Category SubCategory  BuyerOrderQty BuyerOrderDate  \
# 0  SEWING TRIMS    Trims      THREAD          500.0     2022-01-04
# 1         WOVEN  Apparel       JEANS          100.0     2021-11-19
# 2         WOVEN  Apparel       JEANS          100.0     2021-11-19
# 3         WOVEN  Apparel       JEANS          100.0     2021-11-19
# 4         WOVEN  Apparel       JEANS          100.0     2021-11-19
#
#    BuyerOrderValue Currency BuyerDeliveryDate  BuyerShippedQty  \
# 0        1000000.0      INR        2022-01-30              NaN
# 1          10000.0      INR        2021-11-19              NaN
# 2           1000.0      INR        2021-11-19              NaN
# 3          10000.0      INR        2021-11-19              NaN
# 4          10000.0      INR        2021-11-19              NaN
#
#    BuyerShippedValue BuyerShippedInvoiceNo
# 0                NaN                   NaN
# 1                NaN                   NaN
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN

# %%
current_stock_head = current_stock_df.head()
current_stock_head
# Out:
#              SiteName         Category ProductGroup ProductSubCatCode  \
# 0     RM FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 1     RM FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 2     RM FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 3    ABC FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 4  ACHIEVER CUT STORE  Textiles/Fabric       FABRIC            COTTON
#
#                  ArticleName                 ArticleCode ColorName ColorCode  \
# 0  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC     black        20
# 1  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC     black        20
# 2  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC       NaN       NaN
# 3  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC       NaN       NaN
# 4  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC     BLACK   BLACK01
#
#   SizeName SizeCode  ...           GRNNo GRNCreatedBy                 GRNDate  \
# 0   18LINE   18LINE  ...      R-1001-115    tanpreet  2019-02-21 17:33:26.253
# 1      0-3      0-3  ...      R-1001-115    tanpreet  2019-02-21 17:33:26.237
# 2      NaN      NaN  ...             NaN          NaN                     NaT
# 3      NaN      NaN  ...  R-FABSTORE-443     Apoorva  2018-08-16 16:15:11.113
# 4      NaN      NaN  ...             NaN          NaN                     NaT
#
#   Ageing SupplierPONo   UOM Quantity PendingtoDispatch_UnderQC Rate   Value
# 0   2353  F/18.19/549  MTRS    200.0                       0.0  2.5   500.0
# 1   2353  F/18.19/549  MTRS    200.0                       0.0  3.0   600.0
# 2    480          NaN  MTRS    900.0                       0.0  4.0  3600.0
# 3   5365          NaN  MTRS    200.0                       0.0  1.0   200.0
# 4   4187          NaN  MTRS      1.0                       0.0  0.0     0.0
#
# [5 rows x 45 columns]

# %%
metadata_buyer_order_head = metadata_buyer_order_df.head()
metadata_buyer_order_head
# Out:
#         Column_name     Type
# 0         BuyerName  varchar
# 1      BuyerOrderNo  varchar
# 2  BuyerOrderStatus  varchar
# 3         StyleName  varchar
# 4         StyleCode  varchar

# %%
metadata_current_stock_head = metadata_current_stock_df.head()
metadata_current_stock_head
# Out:
#          Column Name     Type
# 0           SiteName  varchar
# 1           Category  varchar
# 2       ProductGroup  varchar
# 3  ProductSubCatCode  varchar
# 4        ArticleName  varchar

# %% [markdown]
# ### Preprocessing Plan before SQLite conversion
# We need to clean both datasets according to their metadata, so your LLM agent can query a consistent database.

# %% [markdown]
# #### Step 1 — Clean BuyerOrder
# * Convert column names to snake_case.
# * Enforce data types from metadata.
# * Handle missing values (NaN → NULL).
# * Normalize dates to YYYY-MM-DD.

# %%
# Make a copy
buyer_order_clean = buyer_order_df.copy()

# %%
# --- 1. Convert column names to snake_case ---
buyer_order_clean.columns = (
    buyer_order_clean.columns.str.strip()
    .str.replace(" ", "_")
    .str.replace("-", "_")
    .str.lower()
)

# %%
# --- 2. Enforce data types based on metadata ---
# Create a metadata dictionary from metadata_buyer_order_df
metadata_dict_buyer = dict(
    zip(metadata_buyer_order_df["Column_name"], metadata_buyer_order_df["Type"])
)

# %%
# Mapping SQL types to pandas types
sql_to_pd_type = {
    "varchar": "string",
    "int": "Int64",
    "float": "float64",
    "date": "datetime64[ns]",
    "datetime": "datetime64[ns]"
}

# %%
# Convert columns to appropriate data types where possible
for col, dtype in metadata_dict_buyer.items():
    col_snake = col.strip().replace(" ", "_").replace("-", "_").lower()
    if col_snake in buyer_order_clean.columns:
        pd_dtype = sql_to_pd_type.get(dtype.lower(), None)
        if pd_dtype:
            try:
                buyer_order_clean[col_snake] = buyer_order_clean[col_snake].astype(pd_dtype)
            except Exception:
                # Coerce errors for dates and numbers
                if "datetime" in pd_dtype or "date" in pd_dtype:
                    buyer_order_clean[col_snake] = pd.to_datetime(buyer_order_clean[col_snake], errors="coerce")
                else:
                    buyer_order_clean[col_snake] = pd.to_numeric(buyer_order_clean[col_snake], errors="coerce")

# %%
# --- 3. Handle missing values (replace NaN with None for SQLite compatibility) ---
buyer_order_clean = buyer_order_clean.where(pd.notnull(buyer_order_clean), None)

# %%
# Preview cleaned BuyerOrder
buyer_order_clean.head()
# Out:
#       buyername        buyerorderno buyerorderstatus  \
# 0  shikha buyer  WFXCompany/OC217.1        Cancelled
# 1  Ashhar Buyer            116180.1        Confirmed
# 2  Ashhar Buyer            116181.1        Confirmed
# 3  Ashhar Buyer            116184.1        Cancelled
# 4  Ashhar Buyer            116186.1        Confirmed
#
#                            stylename                   stylecode  \
# 0  WFX SAMPLE THREAD_2200005_2200005  SEW-THREAD-WFXSAMPLETHREAD
# 1           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 2           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 3           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 4           WFX SAMPLE STYLE_2200006                 JAYDEE10001
#
#    productgroup category subcategory  buyerorderqty buyerorderdate  \
# 0  SEWING TRIMS    Trims      THREAD          500.0     2022-01-04
# 1         WOVEN  Apparel       JEANS          100.0     2021-11-19
# 2         WOVEN  Apparel       JEANS          100.0     2021-11-19
# 3         WOVEN  Apparel       JEANS          100.0     2021-11-19
# 4         WOVEN  Apparel       JEANS          100.0     2021-11-19
#
#    buyerordervalue currency buyerdeliverydate  buyershippedqty  \
# 0        1000000.0      INR        2022-01-30              NaN
# 1          10000.0      INR        2021-11-19              NaN
# 2           1000.0      INR        2021-11-19              NaN
# 3          10000.0      INR        2021-11-19              NaN
# 4          10000.0      INR        2021-11-19              NaN
#
#    buyershippedvalue buyershippedinvoiceno
# 0                NaN                  <NA>
# 1                NaN                  <NA>
# 2                NaN                  <NA>
# 3                NaN                  <NA>
# 4                NaN                  <NA>

# %%
# Save cleaned BuyerOrder to CSV
buyer_order_csv_path ="../data/csv_xlsx/cleaned_BuyerOrder.csv"
buyer_order_clean.to_csv(buyer_order_csv_path, index=False)

# %% [markdown]
# #### Step 2 — Clean CurrentStock
# * Same as above (column names, dtypes).
#
# * Fix inconsistencies (e.g., "BLACK" vs "black", "NaN" in Color).
#
# * Normalize numerical columns.

# %%
# Step 1: Clean CurrentStock DataFrame

# Make a copy
current_stock_clean = current_stock_df.copy()

# %%
# --- 1. Convert column names to snake_case ---
current_stock_clean.columns = (
    current_stock_clean.columns.str.strip()
    .str.replace(" ", "_")
    .str.replace("-", "_")
    .str.lower()
)

# %%
# --- 2. Enforce data types based on metadata ---
# Create a metadata dictionary from metadata_current_stock_df
metadata_dict_stock = dict(
    zip(metadata_current_stock_df["Column Name"], metadata_current_stock_df["Type"])
)

# %%
# Mapping SQL types to pandas types (reuse from BuyerOrder step)
sql_to_pd_type_stock = {
    "varchar": "string",
    "int": "Int64",
    "float": "float64",
    "date": "datetime64[ns]",
    "datetime": "datetime64[ns]"
}

# %%
# Convert columns to appropriate data types where possible
for col, dtype in metadata_dict_stock.items():
    col_snake = col.strip().replace(" ", "_").replace("-", "_").lower()
    if col_snake in current_stock_clean.columns:
        pd_dtype = sql_to_pd_type_stock.get(dtype.lower(), None)
        if pd_dtype:
            try:
                current_stock_clean[col_snake] = current_stock_clean[col_snake].astype(pd_dtype)
            except Exception:
                if "datetime" in pd_dtype or "date" in pd_dtype:
                    current_stock_clean[col_snake] = pd.to_datetime(current_stock_clean[col_snake], errors="coerce")
                else:
                    current_stock_clean[col_snake] = pd.to_numeric(current_stock_clean[col_snake], errors="coerce")

# %%
# --- 3. Handle missing values (replace NaN with None for SQLite compatibility) ---
current_stock_clean = current_stock_clean.where(pd.notnull(current_stock_clean), None)

# %%
# Preview cleaned CurrentStock
current_stock_clean.head()
# Out:
#              sitename         category productgroup productsubcatcode  \
# 0     RM FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 1     RM FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 2     RM FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 3    ABC FABRIC STORE  Textiles/Fabric       FABRIC            COTTON
# 4  ACHIEVER CUT STORE  Textiles/Fabric       FABRIC            COTTON
#
#                  articlename                 articlecode colorname colorcode  \
# 0  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC     black        20
# 1  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC     black        20
# 2  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC      <NA>      <NA>
# 3  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC      <NA>      <NA>
# 4  WFX SAMPLE FABRIC_2200001  FAB-COTTON-WFXSAMPLEFABRIC     BLACK   BLACK01
#
#   sizename sizecode  ...           grnno grncreatedby                 grndate  \
# 0   18LINE   18LINE  ...      R-1001-115    tanpreet  2019-02-21 17:33:26.253
# 1      0-3      0-3  ...      R-1001-115    tanpreet  2019-02-21 17:33:26.237
# 2     <NA>     <NA>  ...            <NA>         <NA>                     NaT
# 3     <NA>     <NA>  ...  R-FABSTORE-443     Apoorva  2018-08-16 16:15:11.113
# 4     <NA>     <NA>  ...            <NA>         <NA>                     NaT
#
#   ageing supplierpono   uom quantity pendingtodispatch_underqc rate   value
# 0   2353  F/18.19/549  MTRS    200.0                       0.0  2.5   500.0
# 1   2353  F/18.19/549  MTRS    200.0                       0.0  3.0   600.0
# 2    480         <NA>  MTRS    900.0                       0.0  4.0  3600.0
# 3   5365         <NA>  MTRS    200.0                       0.0  1.0   200.0
# 4   4187         <NA>  MTRS      1.0                       0.0  0.0     0.0
#
# [5 rows x 45 columns]

# %%
# Save cleaned CurrentStock to CSV
current_stock_csv_path = "../data/csv_xlsx/cleaned_CurrentStock.csv"
current_stock_clean.to_csv(current_stock_csv_path, index=False)

# %% [markdown]
# # Get information about cleaned BuyerOrder CSV

# %%
buyer_order_info = buyer_order_clean.info()
buyer_order_describe = buyer_order_clean.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34426 entries, 0 to 34425
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   buyername              34426 non-null  string
#  1   buyerorderno           34425 non-null  string
#  2   buyerorderstatus       34424 non-null  string
#  3   stylename              34424 non-null  string
#  4   stylecode              34426 non-null  string
#  5   productgroup           34426 non-null  string
#  6   category               34426 non-null  string
#  7   subcategory            34426 non-null  string
#  8   buyerorderqty          34422 non-null  float64
#  9   buyerorderdate         34250 non-null  datetime64[ns]
#  10  buyerordervalue        34245 non-null  float64
#  11  currency               34227 non-null  string
#  12  buyerdeliverydate      34184 non-null  datetime64[ns]
#  13  buyershippedqty        5290 non-null   float64
#  14  buyershippedvalue      5290 non-null   float64
#  15  buyershippedinvoiceno  5291 non-null   string
# dtypes: datetime64[ns](2), float64(4), string(10)
# memory usage: 4.2 MB

# %%
# Get information about cleaned CurrentStock CSV
current_stock_info = current_stock_clean.info()
current_stock_describe = current_stock_clean.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72089 entries, 0 to 72088
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sitename                   72089 non-null  string
#  1   category                   72089 non-null  string
#  2   productgroup               71522 non-null  string
#  3   productsubcatcode          71535 non-null  string
#  4   articlename                71511 non-null  string
#  5   articlecode                72087 non-null  string
#  6   colorname                  62087 non-null  string
#  7   colorcode                  62090 non-null  string
#  8   sizename                   60515 non-null  string
#  9   sizecode                   60652 non-null  string
#  10  shade                      26245 non-null  string
#  11  count                      8410 non-null   string
#  12  content                    30528 non-null  string
#  13  construction               12421 non-null  string
#  14  stocktype                  72089 non-null  string
#  15  quality                    72067 non-null  string
#  16  posupplierref              1202 non-null   string
#  17  locationcode               71449 non-null  string
#  18  indentno                   22638 non-null  string
#  19  stylename                  41118 non-null  string
#  20  stylecode                  41120 non-null  string
#  21  buyerstyleref              23386 non-null  string
#  22  merchandiser               4627 non-null   string
#  23  manager                    22145 non-null  string
#  24  buyer                      49533 non-null  string
#  25  supplier                   16541 non-null  string
#  26  ocnum                      41773 non-null  string
#  27  ocstatus                   40778 non-null  string
#  28  contractno                 71 non-null     string
#  29  contractdate               71 non-null     datetime64[ns]
#  30  contractamount             71 non-null     float64
#  31  sourcebuyer                36054 non-null  string
#  32  pcddate                    3088 non-null   datetime64[ns]
#  33  garmentdeliverydate        40737 non-null  datetime64[ns]
#  34  grndetails                 72089 non-null  string
#  35  grnno                      55006 non-null  string
#  36  grncreatedby               55006 non-null  string
#  37  grndate                    55004 non-null  datetime64[ns]
#  38  ageing                     72089 non-null  Int64
#  39  supplierpono               49397 non-null  string
#  40  uom                        72089 non-null  string
#  41  quantity                   72089 non-null  float64
#  42  pendingtodispatch_underqc  72089 non-null  float64
#  43  rate                       72089 non-null  float64
#  44  value                      72089 non-null  float64
# dtypes: Int64(1), datetime64[ns](4), float64(5), string(35)
# memory usage: 24.8 MB

# %%
buyer_order_summary = {
    "shape": buyer_order_clean.shape,
    "columns": list(buyer_order_clean.columns)
}

# %%
current_stock_summary = {
    "shape": current_stock_clean.shape,
    "columns": list(current_stock_clean.columns)
}

# %%
# Display summaries
print("BuyerOrder Summary:")
buyer_order_clean.head(10)
# Out:
# BuyerOrder Summary:
#       buyername          buyerorderno buyerorderstatus  \
# 0  shikha buyer    WFXCompany/OC217.1        Cancelled
# 1  Ashhar Buyer              116180.1        Confirmed
# 2  Ashhar Buyer              116181.1        Confirmed
# 3  Ashhar Buyer              116184.1        Cancelled
# 4  Ashhar Buyer              116186.1        Confirmed
# 5  Ashhar Buyer              116190.1        Confirmed
# 6  Ashhar Buyer              116191.1           Closed
# 7       WFXUSD1              112349.1        Confirmed
# 8            PB  AoneBuyer/NEWOC/30.1        Confirmed
# 9            PB  AoneBuyer/NEWOC/31.1        Confirmed
#
#                            stylename                   stylecode  \
# 0  WFX SAMPLE THREAD_2200005_2200005  SEW-THREAD-WFXSAMPLETHREAD
# 1           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 2           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 3           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 4           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 5           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 6           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 7           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 8           WFX SAMPLE STYLE_2200006                 JAYDEE10001
# 9           WFX SAMPLE STYLE_2200006                 JAYDEE10001
#
#    productgroup category subcategory  buyerorderqty      buyerorderdate  \
# 0  SEWING TRIMS    Trims      THREAD          500.0 2022-01-04 00:00:00
# 1         WOVEN  Apparel       JEANS          100.0 2021-11-19 00:00:00
# 2         WOVEN  Apparel       JEANS          100.0 2021-11-19 00:00:00
# 3         WOVEN  Apparel       JEANS          100.0 2021-11-19 00:00:00
# 4         WOVEN  Apparel       JEANS          100.0 2021-11-19 00:00:00
# 5         WOVEN  Apparel       JEANS          100.0 2021-11-19 00:00:00
# 6         WOVEN  Apparel       JEANS          100.0 2021-11-19 00:00:00
# 7         WOVEN  Apparel       JEANS           90.0 2020-02-12 11:12:00
# 8         WOVEN  Apparel       JEANS          100.0 2023-09-11 00:00:00
# 9         WOVEN  Apparel       JEANS          100.0 2023-09-11 00:00:00
#
#    buyerordervalue currency buyerdeliverydate  buyershippedqty  \
# 0       1000000.00      INR        2022-01-30              NaN
# 1         10000.00      INR        2021-11-19              NaN
# 2          1000.00      INR        2021-11-19              NaN
# 3         10000.00      INR        2021-11-19              NaN
# 4         10000.00      INR        2021-11-19              NaN
# 5         10000.00      INR        2021-11-19              NaN
# 6         10000.00      INR        2021-11-19              NaN
# 7           945.00      INR        2020-02-12              NaN
# 8           109.00      USD        2023-09-11              NaN
# 9           120.86      USD        2023-09-11              NaN
#
#    buyershippedvalue buyershippedinvoiceno
# 0                NaN                  <NA>
# 1                NaN                  <NA>
# 2                NaN                  <NA>
# 3                NaN                  <NA>
# 4                NaN                  <NA>
# 5                NaN                  <NA>
# 6                NaN                  <NA>
# 7                NaN                  <NA>
# 8                NaN                  <NA>
# 9                NaN                  <NA>

# %%
buyer_order_summary
# Out:
# {'shape': (34426, 16),
#  'columns': ['buyername',
#   'buyerorderno',
#   'buyerorderstatus',
#   'stylename',
#   'stylecode',
#   'productgroup',
#   'category',
#   'subcategory',
#   'buyerorderqty',
#   'buyerorderdate',
#   'buyerordervalue',
#   'currency',
#   'buyerdeliverydate',
#   'buyershippedqty',
#   'buyershippedvalue',
#   'buyershippedinvoiceno']}

# %%
current_stock_summary
# Out:
# {'shape': (72089, 45),
#  'columns': ['sitename',
#   'category',
#   'productgroup',
#   'productsubcatcode',
#   'articlename',
#   'articlecode',
#   'colorname',
#   'colorcode',
#   'sizename',
#   'sizecode',
#   'shade',
#   'count',
#   'content',
#   'construction',
#   'stocktype',
#   'quality',
#   'posupplierref',
#   'locationcode',
#   'indentno',
#   'stylename',
#   'stylecode',
#   'buyerstyleref',
#   'merchandiser',
#   'manager',
#   'buyer',
#   'supplier',
#   'ocnum',
#   'ocstatus',
#   'contractno',
#   'contractdate',
#   'contractamount',
#   'sourcebuyer',
#   'pcddate',
#   'garmentdeliverydate',
#   'grndetails',
#   'grnno',
#   'grncreatedby',
#   'grndate',
#   'ageing',
#   'supplierpono',
#   'uom',
#   'quantity',
#   'pendingtodispatch_underqc',
#   'rate',
#   'value']}
